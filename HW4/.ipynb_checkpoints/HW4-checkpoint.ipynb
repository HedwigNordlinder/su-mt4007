# %% [markdown]
# # Homework 4
# ## Joining data
# We begin by loading the population data from pop_data.csv and our cleaned data from HW3

# %%
population_data <- read.csv("pop_data.csv")
cell_phone_data <- read.csv("cell_phone_data_cleaned.csv")
library("ggplot2")

# %%
# Out:
# plot without title
